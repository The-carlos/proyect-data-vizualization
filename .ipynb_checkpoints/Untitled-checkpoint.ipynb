# %%
"""
Sabado 12 de diciembre.
Vamos a hacer un analisis de algunas vacantes para Data Analysts en todo el mundo (2253 vacantes) y vamos a encontrar Insights
de valor para nosotros como postulantes como:
- Posición más buscada.
- Posición mejor pagada.
- ¿Qué habilidades buscan las empresas con mayor rating?
- ¿Qué habilidades son las mejor pagadas?
- ¿Cuál es el salario al que podríamos aspirar?
- ¿El número de empleados de la empresa influye en el salario que se ofrece?
- Principales responsabilidades y habilidades.
- ¿La antiguedad de la empresa influye en el salario que ofrecen?
"""
# Out:
# '\nSabado 12 de diciembre.\nVamos a hacer un analisis de algunas vacantes para Data Analysts en todo el mundo (2253 vacantes) y vamos a encontrar Insights\nde valor para nosotros como postulantes como:\n- Posición más buscada.\n- ¿Qué habilidades buscan las empresas con mayor rating?\n- ¿Qué habilidades son las mejor pagadas?\n- ¿Cuál es el salario al que podríamos aspirar?\n- ¿El número de empleados de la empresa influye en el salario que se ofrece?\n- Principales responsabilidades y habilidades.\n- ¿La antiguedad de la empresa influye en el salario que ofrecen?\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re

# %%
data = pd.read_csv('DataAnalyst.csv')
data.to_excel('data.xlsx')

# %% [markdown]
# # DataCleaning

# %%
#Le damos un vistazo general al dataset para conocer la data.
data.head(10)

#Desde aqui puedo ver que la primera columna "Unamed: 0" es completament inecesaria.
#Además de que los registros de las columas "Company Name" y "Job Description" contienen valores no deseados (\n, etc).
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
# 5           5                                       Data Analyst
# 6           6                       Business/Data Analyst (FP&A)
# 7           7                               Data Science Analyst
# 8           8                                       Data Analyst
# 9           9                      Data Analyst, Merchant Health
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
# 5  $37K-$66K (Glassdoor est.)
# 6  $37K-$66K (Glassdoor est.)
# 7  $37K-$66K (Glassdoor est.)
# 8  $37K-$66K (Glassdoor est.)
# 9  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# 5  About Cubist\nCubist Systematic Strategies is ...     3.9
# 6  Two Sigma is a different kind of investment ma...     4.4
# 7  Data Science Analyst\n\nJob Details\nLevel\nEx...     3.7
# 8  The Data Analyst is an integral member of the ...     4.0
# 9  About Us\n\nRiskified is the AI platform power...     4.4
#
#                               Company Name      Location  \
# 0           Vera Institute of Justice\n3.2  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY
# 2                         Squarespace\n3.4  New York, NY
# 3                            Celerity\n4.1  New York, NY
# 4                             FanDuel\n3.9  New York, NY
# 5                             Point72\n3.9  New York, NY
# 6                           Two Sigma\n4.4  New York, NY
# 7             GNY Insurance Companies\n3.7  New York, NY
# 8                                DMGT\n4.0  New York, NY
# 9                           Riskified\n4.4  New York, NY
#
#              Headquarters                     Size  Founded  \
# 0            New York, NY     201 to 500 employees     1961
# 1            New York, NY         10000+ employees     1893
# 2            New York, NY   1001 to 5000 employees     2003
# 3              McLean, VA     201 to 500 employees     2002
# 4            New York, NY    501 to 1000 employees     2009
# 5            Stamford, CT   1001 to 5000 employees     2014
# 6            New York, NY   1001 to 5000 employees     2001
# 7            New York, NY     201 to 500 employees     1914
# 8  London, United Kingdom  5001 to 10000 employees     1896
# 9            New York, NY    501 to 1000 employees     2013
#
#                 Type of ownership                               Industry  \
# 0          Nonprofit Organization                      Social Assistance
# 1          Nonprofit Organization       Health Care Services & Hospitals
# 2               Company - Private                               Internet
# 3  Subsidiary or Business Segment                            IT Services
# 4               Company - Private                    Sports & Recreation
# 5               Company - Private  Investment Banking & Asset Management
# 6               Company - Private  Investment Banking & Asset Management
# 7               Company - Private                     Insurance Carriers
# 8                Company - Public       Venture Capital & Private Equity
# 9               Company - Private                 Research & Development
#
#                              Sector                     Revenue  \
# 0                        Non-Profit  $100 to $500 million (USD)
# 1                       Health Care      $2 to $5 billion (USD)
# 2            Information Technology    Unknown / Non-Applicable
# 3            Information Technology   $50 to $100 million (USD)
# 4  Arts, Entertainment & Recreation  $100 to $500 million (USD)
# 5                           Finance    Unknown / Non-Applicable
# 6                           Finance    Unknown / Non-Applicable
# 7                         Insurance  $100 to $500 million (USD)
# 8                           Finance      $1 to $2 billion (USD)
# 9                 Business Services    Unknown / Non-Applicable
#
#                         Competitors Easy Apply
# 0                                -1       True
# 1                                -1         -1
# 2                           GoDaddy         -1
# 3                                -1         -1
# 4                        DraftKings       True
# 5                                -1         -1
# 6                                -1         -1
# 7  Travelers, Chubb, Crum & Forster       True
# 8  Thomson Reuters, Hearst, Pearson         -1
# 9                  Signifyd, Forter         -1

# %%
#Comenzamos por eliminar la columna 'Unnamed: 0'

data = data.drop(['Unnamed: 0'], axis = 'columns')

# %%
data
# Out:
#                                               Job Title  Salary Estimate  \
# 1816                                Junior Data Analyst              0.0
# 2207                                       Data Analyst              0.0
# 1929                                Data Studio Analyst              0.0
# 124                                 Junior Data Analyst              0.0
# 1218                                       Data Analyst              0.0
# ...                                                 ...              ...
# 2200                                       Data Analyst              0.0
# 2202                             Financial Data Analyst              0.0
# 2239                       Senior Contract Data Analyst              0.0
# 2246  Technical Business Analyst (SQL, Data analytic...              0.0
# 2250  Technical Business Analyst (SQL, Data analytic...              0.0
#
#                                         Job Description  Rating  \
# 1816  Job Description\nJob description\nInterpret da...     5.0
# 2207  We are looking for data analysts, data wrangle...     5.0
# 1929  At Priceonomics, our core skill is making data...     5.0
# 124   Job Description\nJob description\nInterpret da...     5.0
# 1218  Job Description\nJob description\nInterpret da...     5.0
# ...                                                 ...     ...
# 2200  Role Data Analyst Duration12+ months Location ...     NaN
# 2202  Position:Financial Data AnalystJob Description...     NaN
# 2239  OverviewAmyx is seeking to hire a Senior Contr...     NaN
# 2246  Spiceorb is looking for Technical Business Ana...     NaN
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
#
#                                      Company Name           Location  \
# 1816                  Staffigo Technical Services      Charlotte, NC
# 2207                          xentity corporation         Denver, CO
# 1929                                 Priceonomics  San Francisco, CA
# 124                   Staffigo Technical Services       New York, NY
# 1218                  Staffigo Technical Services    San Antonio, TX
# ...                                           ...                ...
# 2200        Tech Aspect Solutions Inc dba Digital     Centennial, CO
# 2202  Black Knight Financial Technology Solutions         Denver, CO
# 2239                                    Amyx Iinc         Aurora, CO
# 2246                                     Spiceorb         Denver, CO
# 2250                                     Spiceorb         Denver, CO
#
#            Headquarters                 Size  Founded  Type of ownership  \
# 1816      Woodridge, IL  51 to 200 employees   2008.0  Company - Private
# 2207       Lakewood, CO  51 to 200 employees   2001.0  Company - Private
# 1929  San Francisco, CA    1 to 50 employees      NaN  Company - Private
# 124       Woodridge, IL  51 to 200 employees   2008.0  Company - Private
# 1218      Woodridge, IL  51 to 200 employees   2008.0  Company - Private
# ...                 ...                  ...      ...                ...
# 2200                NaN                  NaN      NaN                NaN
# 2202                NaN                  NaN      NaN                NaN
# 2239                NaN                  NaN      NaN                NaN
# 2246                NaN                  NaN      NaN                NaN
# 2250                NaN                  NaN      NaN                NaN
#
#          Industry                  Sector                     Revenue  \
# 1816  IT Services  Information Technology   $50 to $100 million (USD)
# 2207  IT Services  Information Technology     $5 to $10 million (USD)
# 1929     Internet  Information Technology  Less than $1 million (USD)
# 124   IT Services  Information Technology   $50 to $100 million (USD)
# 1218  IT Services  Information Technology   $50 to $100 million (USD)
# ...           ...                     ...                         ...
# 2200          NaN                     NaN                         NaN
# 2202          NaN                     NaN                         NaN
# 2239          NaN                     NaN                         NaN
# 2246          NaN                     NaN                         NaN
# 2250          NaN                     NaN                         NaN
#
#      Competitors  Easy Apply
# 1816         NaN       False
# 2207         NaN       False
# 1929         NaN       False
# 124          NaN       False
# 1218         NaN       False
# ...          ...         ...
# 2200         NaN       False
# 2202         NaN       False
# 2239         NaN       False
# 2246         NaN       False
# 2250         NaN       False
#
# [2253 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 264.1+ KB

# %%
#Revisamos cuantos valores nulos hay
data.isnull().sum()
#Pareciera que no hay ningún valor nulo, pero vamos a revisar más a detalle:
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
columns = data.columns.tolist()

# %%
columns
for column in columns:
    print(column)
    print(data[column].value_counts())
# Out:
# Job Title
# Data Analyst                                                        405
# Senior Data Analyst                                                  90
# Junior Data Analyst                                                  30
# Business Data Analyst                                                28
# Sr. Data Analyst                                                     21
#                                                                    ...
# Senior Data Analyst w/ Collibra                                       1
# Senior Data Management Analyst, Enterprise Data Management, OCDO      1
# TSDS Data QA Analyst (Data Analyst IV)                                1
# Senior Data Analyst - Informatics                                     1
# Data Systems Analyst III                                              1
# Name: Job Title, Length: 1272, dtype: int64
# Salary Estimate
# $41K-$78K (Glassdoor est.)    57
# $42K-$76K (Glassdoor est.)    57
# $50K-$86K (Glassdoor est.)    41
# $35K-$67K (Glassdoor est.)    33
# $43K-$76K (Glassdoor est.)    31
#                               ..
# $36K-$67K (Glassdoor est.)     3
# $43K-$77K (Glassdoor est.)     3
# $47K-$81K (Glassdoor est.)     3
# $57K-$70K (Glassdoor est.)     2
# -1                             1
# Name: Salary Estimate, Length: 90, dtype: int64
# Job Description
# The Info Sec Prof Lead Analyst is an intermediate level position responsible for driving efforts to prevent, monitor and respond to information/data breaches and cyber-attacks. The overall objective of this role is to ensure the execution of Information Security directives and activities in alignment with Citi's data security policy. Responsibilities: Design and implement a solution for performance measurements on effectiveness of controls and overall vulnerability assessment program Analyze trends on assets security health posture and report using visualization tools for program review with management and stakeholders Analyze and report aggregated data from multiple data sources Develop data visualization mock-ups for monitoring program data trends and communicate using analytical tools Develop reports for tracking program effectiveness and update power point deck for weekly , monthly and quarterly updates Develop, optimize and provide continuous support for reports and ad-hoc queries from end user Create dashboards with parameters and interactive drill down functionality Analyze trends on assets security health posture and report using visualization tools for program review with management and stakeholders Excellent Analytical Ability - Understand the systems and data flow at a high level to evaluate if appropriate controls are in place for the standards Provide timely, accurate, and actionable reporting on application vulnerability activity, trends, service levels, and areas of concern to senior management Streamline and automate report creation and distribution for weekly & monthly reporting Work with the Metrics reporting team to enhance and refine the metrics and key performance indicators reported to senior management and external regulatory agencies Develop User acceptance test plans for testing changes to system enhancements that impact governance and compliance Document business requirements related to system enhancements and submit for reviews and approvals Perform data analysis from multiple systems and assess completeness of data for reporting Ensure data integrity and compliance by performing data audits and data validation Performs root cause analysis on metric trends and provide insight to governance team for appropriate refinements to rules Qualifications: At least 7+ years of strong data analysis and report development experience 7+ years of experience in information security or related technology experience required At least 7+ years experience with Business Intelligence Reporting tools like Cognos, Tableau At least 7+ years experience with Databases like Oracle, SQL Server, Microsoft Access Strong Business Intelligence Developer Skills Strong understanding of application development life cycle, CI/CD and DevOps concepts Excellent Excel data analysis and Access database skills Excellent SQL Skills Experience with issue resolution - ability to research, identify and communicate solutions Excellent documentation skills - Collect, summarize and synthesize information in an auditable format Excellent organization and multi-tasking skills Proven influencing and relationship management skills Education: Bachelors degree in information security, computer science, computer information systems or a related information technology discipline ------------------------------------------------- Grade :All Job Level - All Job FunctionsAll Job Level - All Job Functions - US ------------------------------------------------------ Time Type : ------------------------------------------------------ Citi is an equal opportunity and affirmative action employer. Minority/Female/Veteran/Individuals with Disabilities/Sexual Orientation/Gender Identity. Citigroup Inc. and its subsidiaries ("Citi) invite all qualified interested applicants to apply for career opportunities. If you are a person with a disability and need a reasonable accommodation to use our search tools and/or apply for a career opportunity CLICK HERE . To view the "EEO ...
# The Brink’s name is a promise to respect the trust we’ve earned in over 150 years in business. Every employee honors that promise by offering the highest levels of service and support to our customers. We take pride in our work, and we share a passion about our future. Learn why so many people have made the choice to join our team – and stay here.\n\nJob Title\n\nData Processing & Performance Analyst\n\nJob Description\n\nBrink’s Global Services is a division of Brink’s Inc, the world’s premier provider of secure logistics and security solutions in more than 122 countries across 5 continents. Brink’s Global Services specializes in the secure transportation and handling of valuable goods throughout the logistic value chain, from raw materials and components to finished products within the mining, banknote, precious metal, jewelry, security, art and pharmaceutical industries The company has a proud history of providing growth and advancement opportunities for its employees. We have a challenging opportunity for a Data Processing & Performance Analystbased out of our JFK, New York location.\n\nJob Summary:\nThe Data Processing & Performance Analyst is responsible for overall data gathering, analysis, and administration of: operating procedural, metrics tracking, communication, and TQM & Lean Development initiatives. This position assists with the development and implementation of performance improvement initiatives and controls used in the US Brink’s Global Services (USBGS) network.\n\nKey Responsibilities:\nServe as the primary contact in USBGS for all service-level communications with the USBGS network branches\nDaily follow up with the network for coordination of operational activities\nDaily management of key performance measures such as POD (Proof of Delivery)\nWork closely and objectively with other department personnel to obtain system/process data in support of consolidated performance development\nData entry/data management at large scale\nParticipate in execution, implementation and monitoring of process improvement initiatives and performance metrics\nAuditing of various regulatory compliance requirements and creation of document packets for Customers and relevant Authorities\nWork with branches to ensure process efficiencies are implemented and maintained\nWork with varies departments to assure that branches are providing acceptable levels of service\nConduct Inter-Company Charges (BTC) analysis, and report irregularities and other findings\nProvide reports and analysis, including performance, financial and cost savings summaries\nDevelop process related training programs & materials for both USBGS and branch staff, and conduct on-going training/development initiatives\nTravel to branch locations to conduct inquiries, analysis and audits\nPerform other duties as assigned or necessary\nAbout Brink’s\n\n\nBrink’s is the global leader in security and logistics services, trusted by banks, financial institutions and businesses in both public and private sectors. We deliver the currency of the world to businesses in our communities. We do it because we’re needed. We do it because we’re trusted and valued. We do it because it makes us proud. Brink’s Proud.\n\nWhat’s Next?\n\n\nThank you for considering applying for a job at Brink’s U.S. To be considered for this position, you must complete the entire application process, which includes answering all prescreening questions and providing your eSignature.\n\nUpon completion of the application process, you will receive an email confirming that we have received your application. We will review all candidates and notify you of your status should we deem you fit for a job. Thank you again for your interest in a career at Brink’s U.S. For more information about future career opportunities, join our talent network, Like our Facebook page or Follow us on Twitter.\n\nBrink’s is an equal opportunity/affirmative action employer and all qualified applicants will receive consideration for  ...
# Ref ID: 04160-9502602115Classification: Data Analyst\n\nCompensation: $52.18 to $60.00 hourly\n\nRobert Half Technology is looking for a Data Analyst to help our client in South Austin on an upcoming short term project.\n\nDuties:\nCollect and document business requirements for reporting and analysis initiatives with customers.\nPerform quantitative and/or qualitative data analysis and prepare results to share with internal and external customers.\nAid in design and development of data warehouse/data mart applications.\nUndertake complex data integration activities.\nUtilize SQL or other advanced analytic tools to perform data extract and query functions.\nIdentify and troubleshoot data anomalies and irregularities.\nPrepare written and oral reports that communicate necessary information to internal and external customers.\nWillingness to learn and work with Business Intelligence (BI) tools for extracting and compiling data.\nBecome a data subject matter expert (SME) and understand various sources and applications of CCC data.\nPerforms other duties as assigned.\nJob Requirements:\nUse of statistics to solve problems and perform moderately complex data analysis. - Experience understanding and writing SQL queries in various environments. - Experience developing and troubleshooting programming code (e.g. SQL, SAS, STATA, R). - Demonstrated ability to manage and prioritize multiple projects with varying deadlines. - Compliance with data confidentiality and security procedures. - Perform complex operations in Microsoft Office Suite, with an emphasis on Excel and Access. - Ability to write and speak clearly, easily communicating complex ideas as indicated by audience. - Knowledge of healthcare, including medical claims coding, relationships between health plans, providers, and payers, a plus. MINIMUM EDUCATION AND EXPERIENCE - Bachelors degree in related field required, Masters degree preferred. - 1-3 years of experience with data management and statistical analysis. - Proficiency in using SQL for database queries. - Experience in a health or healthcare field. - Experience using statistical analysis software such as SAS, R, or STATA is desirable but not required. - Any equivalent combination of education and/or experience may substitute Apply today if interested.\nRobert Half Technology matches IT professionals with some of the best companies on a temporary, project or full-time basis. From roles in software and applications to IT infrastructure and operations, we provide you unparalleled access to exciting career opportunities. Our personalized approach, innovative matching technology and global network with local market expertise help you find the technology jobs that match your skills and priorities fast. By working with us, you have access to challenging opportunities, competitive compensation and benefits, and training to enhance your skill sets.\n\nFrom philanthropy to environmental stewardship to employee programs, Robert Half is proud to have an active role in the communities in which we live and work. Our company has appeared on FORTUNEs Most Admired Companies list every year since 1998.\n\nDownload our mobile app to take your job search on the go!\n\nContact your local Robert Half Technology office at 888.490.4429 or visit www.roberthalf.com/jobs/technology to apply for this job now or find out more about other job opportunities.\n\nAll applicants applying for U.S. job openings must be authorized to work in the United States. All applicants applying for Canadian job openings must be authorized to work in Canada.\n\n© 2020 Robert Half Technology. An Equal Opportunity Employer M/F/Disability/Veterans.\n\nBy clicking 'Apply Now' you are agreeing to Robert Half Terms of Use.                                                                                                                                                                                                                                                                 ...
# Hello,\n\nHope you are doing great.\n\nOne of my clients is looking to fill this position immediately\n\nLooking forward for your Quick Reply...\n\nJob title: Data Analyst with Teradata Exp.\n\nWork Location: Sunnyvale CA 94085\n\nDuration of the project : 24+ months\n\nJob Description:\nMust Have Skills (Top 3 technical skills only) *\nTeradata\nPython\nSAP BOBJ\n\nNice to have skills\nVertica\nSAP HANA\n\nDetailed Job Description\nCoordinating with business upholders, application developers, and client management.\nProviding essential inputs to the global teams supporting the applications.\nIncident management, coordinating periodic system upgrades, compliance related changes for the applications used by business teams for daytoday analysis, and trend reporting.\nReviewing application enhancements and new releases to work smoothly with the platforms.\nAnalyzing issues reported by business analysts and providing technical solutions.\n\nTop 3 responsibilities you would expect the Subcon to shoulder and execute\nSteadystate maintenance of business intelligence applications\nEmergency modifications and data corrections.\nDoing different housekeeping activities like application maintenance, technical version upgrades.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# Lead Data Insights Analyst Overview\n\nTapRm's growing team is seeking to hire a motivated,responsible and forward-thinking individual to play an integral role in thegrowth and expansion of TapRm's E-Commerce business. This is truly a unique opportunityto build and take ownership over a high-growth companys data analytics andbusiness insights efforts with the unique ability to apply data-driven approachesacross all facets of the operation, including website structure andorganization, digital marketing, brewery and brand partner relationshipdevelopment and management, and operational efficiency. At the early stages ofa high-growth company, this job's projects may vary day by day, and we'relooking for someone who relishes the opportunity to dive into new challengesand learn new skills along the way. This position will report to TapRm's Headof E-Commerce and is eligible for stock options so that our new Lead DataInsights Analyst can gradually build upon our functional capabilities and growwith the company. We expect that a hard-working person who fits TapRm's culturein this role will grow into additional responsibilities and lead a team withinTapRm over time. Compensation will be commensurate with experience.\n\nAbout TapRm\n\nTapRm is a startup beer and beverage distribution companywith a one-of-a-kind model that benefits brewers, retailers and consumersalike. As the nation's first venture-backed, omnichannel platform for buildingbeer, cider, and hard seltzer brands, TapRm offers an unprecedented pathway forboth established and up-and-coming beverage producers to access and engagecustomers in New York. In short, TapRm has the unique capability to bring NewYorkers favorite beverages to wherever they may be enjoyed--bars, restaurants,markets, offices, and even directly to the home.\n\nKey Responsibilities Include\n\n- Build and take ownership over data analyticsand business insights at TapRm\n\n- Using tools such as Tableau, Looker and GoogleData Studio to aggregate data from across our software tools to build anddevelop dashboards for both client-facing and internal purposes across thecompany that feature relevant KPIs and metrics\n\n- Produce and articulate actionable insights to companyleaders to help drive and prioritize current project pipeline\n\n- Provide quantitative support for potentialproject proposals and perform ad-hoc analyses after the projects have beenimplemented to measure their efficacy\n\nIdealCandidate's Experience & Qualifications\n\n- Graduated with a BA/BS from an accrediteduniversity with an excellent track record\n\n- Obsession with applying data-driven approaches andstructure to complex problems in the never-ending pursuit for increasedefficiency in all of its forms\n\n- Uniquely ability to think high-level to developstrategic initiatives but also be curious and detail-oriented to then executethese strategies as planned\n\n- 3+ years experience in a business insights ordata insights role that had an emphasis on communicating with business leaders toproduce insights beyond simply producing analyses\n\n- Experience specifically analyzing sales data,website data, the accompanying data from Google Analytics and Facebook Pixel,along with marketing channels to produce insights, run A/B tests, etc.\n\n- Proficiency in multiple business intelligencetools with expertise in either Tableau, Looker or Google Data Studio\n\n- Proficiency in Microsoft Excel with the abilityto structure, manipulate and analyze data as though it's second nature\n\n- Exceptional written and verbal communication\n\n- Comfortable with uncertainty and ability toadapt to new projects and situations with a positive attitude\n\n- Extremely well-organized with strong attentionto detail\n\n- Self-starter with an entrepreneurial mindset,proactively diving into projects without having to be asked\n\nBonus Points\n\n- Experience in a startup environment,specifically e-commerce\n\n- Working knowledge of SQL, R, or Python\n\n- High-level understandin ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Project Overview\n\nThe Enterprise Data Governance Project aims to enable NYPA to manage its "Data-As-An-Asset” and to build the foundation for an enterprise data analytics platform at NYPA. This program will focus on enabling data stewardship, improving the quality of our data assets, increasing data security and protection, simplifying data integration and establishing better audit trail on data usage at NYPA\nThis program will implement Data Governance & Data Integration tools and processes to provide data owners and data consumers the ability to provision and access high quality, well-governed data for their day-to-day operations. In addition, it will help establish a strong foundation upon which to build a world-class Data Analytics capability that turns data into business insights more efficiently and effectively.\nJob Functions & Responsibilities\n\nExecution of the Data Discovery Project Phase 2\no Conduct data discovery stakeholder interviews with business and IT stakeholders (selected applications)\no Identify data sets, develop data flows, understand data-related processes and identify key data issues for each application\no Update of Enterprise Data Flow diagrams and Enterprise Data Catalog inventory\no Creation of Application Playback decks and Data Discovery report & presentation\nEnablement of Data Roles within NYPA\no Maintenance of datasets and data roles in the Enterprise Data Catalog - additions, updates and deletions\no Identification of updates / changes to existing data roles for the datasets in the NYPA Data Catalog\no Perform onboarding, transition and education of NYPA stakeholders for the Data Roles at the enterprise (Data Owner, Data Steward, Data Custodian)\no Conduct of quarterly Data Owner meetings to communicate upcoming Data Governance initiatives / processes / policies / best practices\nLead in onboarding and implementation of Collibra Data Governance tool\no Onboarding of new datasets into Data Governance tool\no Establishment of Data Catalog and shop-for-data feature in Data Governance tool\no Manage metadata ingestion (manual and automated) from different sources\no Creation of new workflows in Collibra Data Governance tool\nNew custom workflow for Data Access Request\nNew custom workflow for Business Glossary – from proposal to approval\nNew custom workflow for asset creation, review and validation\no Training and onboarding of NYPA stakeholders to Collibra\nDevelopment of new Data Governance Policies, Procedures and Standards\nDevelop and operationalize new Data Access Request process\no Design of new Enterprise Data Request Process, based on ongoing pilot feedback\no Implementation of new Data Request Process - app by app – working with application owners and business stakeholders\no Communication and training of all enterprise users on new Data Request Process\nDevelopment and execution of Change Management plan for Data Discovery, Data Access Request and operationalization of new Data Governance workflows\nSkills\n\n• Strong knowledge of Data Governance & Quality - policies, processes and tools\n• Strong experience & expertise in using Collibra Data Governance tool\n• Knowledge (experience preferred) using Trillium Data Quality tool and integration with Collibra\n• Working experience in implementing Data Governance policies and processes\n• Strong presentation & communication skills\n• Ability to work with Senior Leaders\n• Experience working on teams that work under Agile principles\nEducation & Certifications\n\n• Undergraduate degree in Engineering, Computer Science, Data Management, or similar field of study. Graduate degree preferred.\n• 3+ years of demonstrated Data Governance experience\n• Minimum of Level 2 Certification in Collibra required                                                                                                                                                                                                                                                   ...
# Business Analyst - Data Science SQL Location Philadelphia, PA 19103 Serves as a liaison between the business community and the IT organization in order to provide technical solutions to meet user needs. Possesses expertise in the business unit(s) they support, as well as, an understanding of the IT organizationrsquos systems and capabilities. Analyzes business partnerrsquos operations to understand their strengths and weaknesses to determine opportunities to automate processes and functions. Assists in the business process redesign and documentation as needed for new technology. Translates high level business requirements into functional specifications for the IT organization and manages changes to such specifications. Educates the IT organization on the direction of the business. Negotiates agreements and commitments by facilitating communication between business unit(s) and IT from initial requirements to final implementation. Possesses an understanding of technological trends and uses this knowledge to bring solutions to business units supported to enhance the enterprisersquos competitive edge. May make recommendations for buy versus build decision. Bachelor's Degree in Computer Science, Information Systems, Business Administration, or other related field or equivalent work experience. Must have 3 - 6 years of relevant technical or business work experience.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# Job Description\nWe have partnered with a large Mining and Metals company in the Sun Valley, CA area to provide them with a Data Analyst.\n\nPlease review the below description and if you are interested please contact:\nVahidin Topcagic at vtopcagic@relevante.biz, 314-853-6670\nResponsibilities of the Data Analyst:\nEnsures business systems are efficient and operating in supported environments\nProactively reviews the business operations for ongoing process improvements\nWorks with process owners to document detailed business requirements\nCoordinates with IT, consultants and process owners to validate solutions\nAnalyses processes and dependencies across integrated software applications\nPrepares functional documents and technical specifications, RFP's, RFI's, etc.\nRecommends new functionality, middleware for ERP, CRM and related applications\nProposes solutions to improve productivity and or save operating capital\nDrives development, acceptance testing and subsequent promotion of changes\nPrioritizes projects and various change requests in conjunction with management\nCoordinates upgrades and data integration efforts with the HRIS users\nProven SQL experience in writing queries and user dashboards in a manufacturing/distribution and/or production environment.\nDevelops SQL Queries and Smart Views with SQL reporting services\nParticipates in the back-end maintenance of SQL based applications as needed\nSupports point of sale systems and credit card devices for retail operations\nUtilizes Microsoft Office (Word, Excel and PowerPoint) to present analysis\nImplements Cross-Functional strategy and methods to solve systems issues\nEvaluates new functional requests, business impacts and recommends solutions\nWorks with Quality and Safety teams to ensure process meets all requirements\nCoordinates with Infrastructure and Help Desk teams to ensure project readiness\nParticipates in the Business Continuity Planning design and implementation\nAttends and participates in regular planning and staff meetings\nLiaison with process owners, application support, end users and customers\nAssists the Help Desk in problem resolution for corporate applications\nWorks closely and assists the Business Systems Manager\nMay be required to travel to various office branches as needed\nQualifications of the Data Analyst:\n\nThe following are the minimum qualifications which an individual requires in order to successfully perform the duties and responsibilities of this position. Please note that the minimum qualifications may vary based upon the department size and/or geographic location.\nDriven professional attitude, enthusiastic, self-reliant\nSelf-motivated, responsible and reliable\nExcellent interpersonal and communication skills\nDetail oriented with strong analytical and problem-solving skills.\nAbility to drive projects from concept to completion\nNegotiating skills\nStrong sense of ownership of issues\nUnderstands the value of human capital\nRequirements of the Data Analyst:\n\nThe ideal candidate will have experience with any combination of the following:\nExperience with a major ERP system and ……solutions Epicor BisTrack and Microsoft Dynamics GP in a Terminal Server environment\nDatabases such as Microsoft SQL Server 2014\nNesting applications such as SigmaNEST\nCustomer Relationship Management (CRM) such as Salesforce\nHRIS applications such as Ascentis\nMedium to large scale ERP/CRM/HRIS application experience\nExperience in the metals industry, supply chain, distribution or retail sales environments\nExperience working across multiple geographic locations using video conferencing\nBenefits of the Data Analyst:\nHealth Insurance\nDental Insurance\nLife Insurance\n401 (k)                                                                                                                                                                                                                                                                                 ...
# Two Sigma is a different kind of investment manager. Since 2001, we have used data science and technology to derive insights that forecast the future and discover value in markets worldwide. Our team of scientists, technologists and academics looks beyond traditional finance to understand the bigger picture and develop creative solutions to some of the world’s most difficult economic problems. Our work spans markets and industries, from insurance and securities to private investments and new ventures.\n\nWe are seeking a business / data analyst to join our Financial Planning and Analysis (FP&A) team. Our group supports the firm’s Management Committee and business leads by producing key metrics highlighting the financial performance of the firm and each of the business units in order to drive critical business decisions. Successful candidates will have the opportunity to shape and influence the growth and strategy of the firm through insightful, data-driven analyses.\n\nYou will take on the following responsibilities:\nManage our financial data platform by partnering with engineering to maintain and design reporting/analytic tools\nEnhance existing data schema and improve process management\nDeliver analyses on business unit profitability and resource / cost allocations to support decision making\nPartner with business leaders to deliver the annual budget, along with quarterly updates, outlining the strategic outlook of the firm\nAct as the key contact for expense analytics across our various business units and key initiatives\nFuture responsibilities will include:\nPartnering with business leaders to launch new business initiatives / product development\nInstituting innovative reporting, analytics, and policy to influence behavior across the firm\nIncorporating FP&A practices across Modeling, Engineering and Corporate areas (e.g. cost optimization, resource allocations, etc.)\nProject lead on high exposure initiatives across the firm\nYou should possess the following qualifications:\n1-5 years of relevant work experience (business analytics)\nBachelor’s degree in Finance/Computer Science/Engineering/Mathematics or related field\nAbility to work with structured data\nExperience with programming languages (ex. Python, SQL)\nStrong analytical and financial modeling skills\nAttention to detail\nStrong Excel skills\nExcellent communication and presentation skills\nYou will enjoy the following benefits:\nCore Benefits: Fully paid medical and dental insurance premiums for employees and dependents, competitive 401k match, employer-paid life & disability insurance\nPerks: Onsite gyms with laundry service, wellness activities, casual dress, snacks, game rooms\nLearning: Tuition reimbursement, conference and training sponsorship\nTime Off: Generous vacation and unlimited sick days, competitive paid caregiver leaves\nWe are proud to be an equal opportunity workplace. We do not discriminate based upon race, religion, color, national origin, sex, sexual orientation, gender identity/expression, age, status as a protected veteran, status as an individual with a disability, or any other applicable legally protected characteristics.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# At Jackson Hewitt, we are working hard for the hardest working and we are on a mission to completely change the way our customers engage with their personal finances. Jackson Hewitt combines the fun, fast-paced culture of a startup with the scale and reputation of one of the nation's largest retailers (over 6,000 locations).We have a passion for our employees and our customers. We recognize and appreciate that our team members are our single greatest competitive advantage. Being an industry leader requires a consistent focus on quality, innovation, performance and results.If you love to roll in data, have an eagerness to find insights from disparate data sources, help improve products and operations with data-supported hypothesis testing, then this role is for you. This is a hands-on technical role with significant overlap engaging with business leaders. Excellent opportunity for those who want to grow into a technical manager role in data and business analytics.The Sr. Business Analyst, Data Science has a key role in Jackson Hewitt's strategic planning and data-driven decision making. This role will work closely with members from Strategy and Data Science teams. The Sr. Business Analyst is expected to perform rigorous data analytics, data visualization, and support other data initiatives across the org.What you'll do here:* Data extraction, synthesis, and finding insights from production databases* Translate business objectives into actionable technical work* Perform hypothesis testing via statistical packages, scripting and visualization* Design and implementation of analytical models, including machine learning modeling with guidance* Translate data insights into business recommendations* Prompt stakeholder management via excellent written and verbal communication skillsSkills you'll bring for success:Minimum Qualifications* Bachelor's degree in analytical field and 2+ years of industry experience in an analytical role (or) a Master's degree with 1+ years' experience in an analytical role* Exceptional SQL skills, at least 1+ year's professional experience extracting large sets of data, and design of ETL flows or data pipelines* Strong Python skills, at least 1+ year's professional experience working with statistical packages (ex: Pandas, NumPy, SciPy, Scikit-learn etc.)* Prior experience developing analytical models using scripting languages* Prior experience with data visualization (e.g. Matplotlib, Tableau, Qlik, Power BI, etc.)* Proven problem solving skills, project management skills, attention to detail, and exceptional organizational skills* Self-driven and able to deliver on ambiguous projects with incomplete dataPreferred Qualifications* Master's degree in Business Analytics, Data Science, Statistics, Econometrics, Mathematics or related quantitative field or an MBA with a concentration in Quantitative Analysis* 2+ years of relevant industry experience as a Business Analyst, Data Analyst, Data Scientist or a statistical analysis role* Prior experience in software development* Prior experience in performing analytical work with AWS components* Prior experience developing requirements and formulating business metrics for reporting* Proficiency in Excel and PowerPoint* Working knowledge of data mining using advanced ETL tools (ex: Beam, DataFlow, Spark, etc.)What you will get if you join us:* Competitive Salary + Bonus* 21 Days Paid Time Off + 11 Paid Holidays* 401k* Medical, Dental, and Vision* Commuter Benefits* Pet Insurance* Company Celebrations and Appreciation Events* Fast-paced, innovative culture with an open and collaborative environment* Ample opportunity to develop core and new skillsets and have a stake in your own success* Freedom to create your best work and make a visible impact on the organization* Opportunities for advancement within the organizationWe appreciate your interest in Jackson Hewitt Tax Service. Jackson Hewitt Tax Service is an equal employment opportunity employer. The Company's policy is  ...
# Name: Job Description, Length: 2253, dtype: int64
# Rating
# -1.0    272
#  3.9    140
#  3.6    135
#  3.7    132
#  5.0    131
#  3.8    130
#  4.0    129
#  3.5    125
#  4.1    119
#  3.3    109
#  3.4    101
#  3.2     91
#  3.1     68
#  3.0     57
#  4.3     55
#  4.2     47
#  4.5     47
#  4.6     46
#  4.4     46
#  2.8     43
#  2.9     40
#  2.5     32
#  4.8     29
#  2.7     25
#  4.7     23
#  4.9     17
#  2.6     14
#  2.4     10
#  1.0     10
#  2.3      9
#  2.0      6
#  2.1      4
#  2.2      3
#  1.6      2
#  1.8      2
#  1.9      2
#  1.7      2
# Name: Rating, dtype: int64
# Company Name
# Staffigo Technical Services, LLC\n5.0    58
# Diverse Lynx\n3.9                        22
# Kforce\n4.1                              19
# Lorven Technologies Inc\n4.0             19
# Robert Half\n3.5                         14
#                                          ..
# Meridian Technologies\n4.0                1
# Smith Hanley Associates\n4.5              1
# Change Healthcare\n2.7                    1
# IT Coalition\n4.3                         1
# Envision Physician Services\n3.6          1
# Name: Company Name, Length: 1513, dtype: int64
# Location
# New York, NY         310
# Chicago, IL          130
# San Francisco, CA    119
# Austin, TX            81
# Los Angeles, CA       80
#                     ...
# Itasca, IL             1
# Ridley Park, PA        1
# Secaucus, NJ           1
# Radnor, PA             1
# Hanford, CA            1
# Name: Location, Length: 253, dtype: int64
# Headquarters
# New York, NY              206
# -1                        172
# San Francisco, CA          71
# Chicago, IL                66
# Woodridge, IL              58
#                          ...
# Annapolis Junction, MD      1
# Kennesaw, GA                1
# West Orange, NJ             1
# New Delhi, India            1
# Aurora, IL                  1
# Name: Headquarters, Length: 483, dtype: int64
# Size
# 51 to 200 employees        421
# 10000+ employees           375
# 1001 to 5000 employees     348
# 1 to 50 employees          347
# 201 to 500 employees       249
# 501 to 1000 employees      211
# -1                         163
# 5001 to 10000 employees     97
# Unknown                     42
# Name: Size, dtype: int64
# Founded
# -1       660
#  2008     80
#  1996     54
#  2000     54
#  2002     54
#         ...
#  1924      1
#  1922      1
#  1918      1
#  1908      1
#  1682      1
# Name: Founded, Length: 161, dtype: int64
# Type of ownership
# Company - Private                 1273
# Company - Public                   452
# -1                                 163
# Nonprofit Organization             124
# Subsidiary or Business Segment      89
# Government                          37
# College / University                34
# Hospital                            19
# Unknown                             16
# Other Organization                  13
# Contract                            11
# School / School District             9
# Private Practice / Firm              9
# Self-employed                        2
# Franchise                            2
# Name: Type of ownership, dtype: int64
# Industry
# -1                                     353
# IT Services                            325
# Staffing & Outsourcing                 323
# Health Care Services & Hospitals       151
# Consulting                             111
#                                       ...
# Metals Brokers                           1
# News Outlet                              1
# Catering & Food Service Contractors      1
# Audiovisual                              1
# Truck Rental & Leasing                   1
# Name: Industry, Length: 89, dtype: int64
# Sector
# Information Technology                570
# Business Services                     524
# -1                                    353
# Finance                               169
# Health Care                           151
# Education                              52
# Insurance                              51
# Accounting & Legal                     43
# Media                                  42
# Manufacturing                          40
# Retail                                 38
# Government                             36
# Biotech & Pharmaceuticals              33
# Non-Profit                             26
# Aerospace & Defense                    22
# Transportation & Logistics             20
# Construction, Repair & Maintenance     16
# Consumer Services                      14
# Oil, Gas, Energy & Utilities           13
# Real Estate                            12
# Telecommunications                     11
# Restaurants, Bars & Food Services       8
# Arts, Entertainment & Recreation        7
# Travel & Tourism                        1
# Mining & Metals                         1
# Name: Sector, dtype: int64
# Revenue
# Unknown / Non-Applicable            615
# $100 to $500 million (USD)          218
# $50 to $100 million (USD)           199
# $10+ billion (USD)                  189
# -1                                  163
# $10 to $25 million (USD)            132
# $2 to $5 billion (USD)              129
# $1 to $5 million (USD)              111
# $25 to $50 million (USD)            110
# Less than $1 million (USD)           93
# $1 to $2 billion (USD)               87
# $500 million to $1 billion (USD)     79
# $5 to $10 million (USD)              72
# $5 to $10 billion (USD)              56
# Name: Revenue, dtype: int64
# Competitors
# -1                                             1732
# Robert Half, Insight Global                      14
# Adecco, Manpower                                 14
# Google, Microsoft, Samsung Electronics           10
# TEKsystems, Insight Global, Accenture            10
#                                                ...
# C.H. Robinson, Transplace                         1
# RBC                                               1
# DraftKings                                        1
# SDL, Keywords Studios, TransPerfect               1
# Intercontinental Exchange, Euronext, Nasdaq       1
# Name: Competitors, Length: 291, dtype: int64
# Easy Apply
# -1      2173
# True      80
# Name: Easy Apply, dtype: int64

# %% [markdown]
# ### De las líneas de arriba puedo concluir que las siguientes columnas comparten un valor nulo [-1.0, -1 y '-1'] (Rating, Founded, Type of ownership, Industry, Sector, Competitors, Easy Apply), para que podamos identificarlos como nulos debemos reemplazar estos valores por un np.nan. Vamos a hacerlo:

# %%
data = data.replace(-1, np.nan)
data = data.replace(-1.0, np.nan)
data = data.replace('-1', np.nan)

#Verificamos que esto se haya realizado con éxito:
data.isnull().sum()
# Out:
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                272
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded               660
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply           2173
# dtype: int64

# %%
#Las únicas variables que podrían preocupar por el hecho de que son nulas son "Competitors" e "Easy Apply"
#Para el caso de la columna "Easy Apply" podemos pensar que si es negativa debe ser porque la empresa no está contratando
# De cualquierforma es más práctico manejar esta columna con un boolean:

data['Easy Apply']=data['Easy Apply'].fillna(False).astype('bool')

# %%
data['Easy Apply']
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2248    False
# 2249    False
# 2250    False
# 2251    False
# 2252    False
# Name: Easy Apply, Length: 2253, dtype: bool

# %%
#Filtramos los registros con Easy Apply
df_easy_apply=data[data['Easy Apply']==True]

#Hacemos un nuevo df contando las empresas que sí tienen easy apply y contamos cuantos puestos para easy aplly ofertan
df=df_easy_apply.groupby('Company Name')['Easy Apply'].count().reset_index()

#Despues mostramos el top 10 de empresas que más vacantes ofertan
company_opening_df=df.sort_values('Easy Apply',ascending=False).head(10)
print(company_opening_df)
# Out:
#                        Company Name  Easy Apply
# 3                 Apex Systems\n3.8          10
# 1    22nd Century Technologies\n3.7           5
# 9                        Chime\n4.8           3
# 47              Signify Health\n3.6           3
# 0        22nd Century Staffing\n4.3           2
# 54                   Undertone\n3.8           2
# 51                 Tempus Labs\n3.2           2
# 43                     Remitly\n4.3           1
# 33         NJF Global Holdings\n4.2           1
# 34  National Kidney Foundation\n3.2           1

# %% [markdown]
# ## Para este punto terminamos el Data Cleaning y podemos comenzar a obtener algunos insgths

# %% [markdown]
# # Posición más buscada.

# %%
#Obtenemos todas las posiciones  
job_title_clear = data['Job Title']


wordCloud = WordCloud(width=450,height= 300).generate(' '.join(job_title_clear))
plt.figure(figsize=(19,9))
plt.axis('off')
plt.title(data['Job Title'].name,fontsize=20)
plt.imshow(wordCloud)
plt.show()

# %%
#Vamos a exportar la Data limpia a un nuevo archivo csv,a partir de este punto solo voy a regresar a Jupyter para obtener una 
#Grafica especifica

# %% [markdown]
# ## Obtenemos el top 15 de las posiciones más buscadas

# %%
#Utilizamos Value_count par obtener la frcuencia en que se repite cada posición y creamos un DataFrame con esta info
#Depues utilizamos rename axis para que las posiciones no queden como ids de rows y reset_ index para renombrar la columna de count
sorted_job_titles = data['Job Title'].value_counts().rename_axis('Job Title').reset_index(name='Vacancies')

#Despues usamos iloc para tomar los primeros 25 puestos
top_10_job_titles = pd.DataFrame(sorted_job_titles.iloc[0:25])


#utilizamos drop() para eliminar los indices con posiciones que no son valiosas para nuestro analisis
top_10_job_titles = top_10_job_titles.drop(top_10_job_titles.index[[0,4,5,6,7,12,13]])

#Hacemos un reset a los inices para que se muestren con normalidad.
top_10_job_titles = top_10_job_titles.reset_index(drop=True)

#utilizamos drop() para eliminar los indices con posiciones que no son valiosas para nuestro analisis
top_10_job_titles = top_10_job_titles.drop(top_10_job_titles.index[[8]])

#Hacemos un reset a los inices para que se muestren con normalidad.
top_10_job_titles = top_10_job_titles.reset_index(drop=True)

#Finalmente guardamos el Data Frame con las posiciones más buscadas:
top_10_job_titles.to_excel('top_10_job_titles.xlsx')

top_10_job_titles
# Out:
#                   Job Title  Vacancies
# 0       Senior Data Analyst         90
# 1       Junior Data Analyst         30
# 2     Business Data Analyst         28
# 3   Data Governance Analyst         16
# 4         Lead Data Analyst         15
# 5    Data Reporting Analyst         13
# 6    Financial Data Analyst         12
# 7    Marketing Data Analyst          9
# 8    Data Warehouse Analyst          8
# 9   Data Management Analyst          8
# 10     Data Science Analyst          7
# 11         SQL Data Analyst          7
# 12   Technical Data Analyst          7
# 13    Data Security Analyst          6
# 14  Healthcare Data Analyst          6
# 15    Clinical Data Analyst          6
# 16    Research Data Analyst          6

# %%
#tamaños
plt.figure(figsize=(20,10))
#Agregar titulo
plt.title('Vacantes más buscadas.', fontsize = 14)

plt.xticks(rotation = 'vertical')
plt.bar(top_10_job_titles['Job Title'],top_10_job_titles['Vacancies'])
plt.show()

# %% [markdown]
# ## ¿Qué habilidades buscan las empresas con mayor rating?

# %%
#Tenemos un problema para obtener esta respuesta. La coumna de company tiene concatenado el rating de la misma empresa.
#Vamos a hacer Data Cleaning a esta columna:

#Primero convertimos la columna a un dictionary 
companies = dict(data['Company Name'])

#Despues hacemos una lista unicamente con los valores del diccionario
companies_list = list(companies.values())

#Iteramos en los elementos de la lista y aplicamos regex buscando \w[a-z]+ que serìa \w para la primera letra mayuscula
#Despues una o más letras minusculas y como findall nos trae una lista de coincidencias usamos un .join() para tener el string
#Del nombre de la compañía
companies_list_clear = [' '.join(re.findall(r'\w[a-z]+', str(element))) for element in companies_list]
data['Company Name'] = companies_list_clear

# %%
#Despues tenemos que resolver las habilidades más buscadas

#Obtenemos todas los requerimientos 
#job_description = data['Job Description']


job_description = list(dict(data['Job Description']).values())
job_description = ' '.join(job_description)
sql = re.findall('SQL',job_description)
python = re.findall('python',job_description)
excel = re.findall('excel',job_description)
data_vis = re.findall('data visualization',job_description)
dashboard = re.findall('dashboard',job_description)
statistics = re.findall('statistics',job_description)
b_data = re.findall('big data',job_description)
data_mining = re.findall('data minig',job_description)
machine_l = re.findall('machine learning',job_description)
ai = re.findall('ai',job_description)
tableau = re.findall('tableau',job_description)
power_bi = re.findall('power bi',job_description)
Spreadsheets = re.findall('Spreadsheets',job_description)
Data_warehousing = re.findall('Data warehousing',job_description)
git = re.findall('git',job_description) 

total = sql + python + excel + data_vis + dashboard + statistics + b_data + data_mining + machine_l + ai + tableau + Spreadsheets + Data_warehousing


print(len(python))
print(len(sql))
print(len(total))

#wordCloud = WordCloud(width=450,height= 300).generate(' '.join(job_description))
wordCloud = WordCloud(width=450,height= 300).generate(' '.join(total))
plt.figure(figsize=(19,9))
plt.axis('off')
plt.title(data['Job Description'].name,fontsize=20)
plt.imshow(wordCloud)
plt.show()
# Out:
# 27
# 2636
# 15478

# %%
#Ordenamos el DataFrame por el rating:

data = data.sort_values(by=['Rating'], ascending=False)

top_rated_companies = data[data.Rating >= 4.1][['Job Description', 'Company Name', 'Rating']]

print(top_rated_companies)

# %% [markdown]
# ## Posiciones mejor pagadas.

# %%
data
# Out:
#                                           Job Title  \
# 1816                            Junior Data Analyst
# 491           Senior Data Analyst- Secret Clearance
# 647             Operations Analyst, Data Governance
# 2181                                   Data Analyst
# 551                                    Data Analyst
# ...                                             ...
# 1915                            DATA Analyst-Remote
# 547                                    Data Analyst
# 558                                    Data Analyst
# 1120                        Business / Data Analyst
# 1940  Data Analyst (College & Foundation Reporting)
#
#                   Salary Estimate  \
# 1816   $50K-$86K (Glassdoor est.)
# 491   $49K-$112K (Glassdoor est.)
# 647    $42K-$66K (Glassdoor est.)
# 2181   $57K-$67K (Glassdoor est.)
# 551    $37K-$70K (Glassdoor est.)
# ...                           ...
# 1915  $99K-$178K (Glassdoor est.)
# 547    $37K-$70K (Glassdoor est.)
# 558    $37K-$70K (Glassdoor est.)
# 1120   $38K-$68K (Glassdoor est.)
# 1940  $99K-$178K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 1816  Job Description\nJob description\nInterpret da...     5.0
# 491   Senior Data Analyst- Secret Clearance- Norfolk...     5.0
# 647   The Job\n\nWarner Bros. Content Technology and...     5.0
# 2181  Job Description\nThe Role\nCome help our custo...     5.0
# 551   We are looking for a data analyst with skills ...     5.0
# ...                                                 ...     ...
# 1915  Software Guidance & Assistance, Inc., (SGA), i...    -1.0
# 547   Company\n\nKharon is a research and data analy...    -1.0
# 558   Data Analyst\n\nOnline Retailer\n\nTorrence CA...    -1.0
# 1120  RESPONSIBILITIES Kforce has a client in search...    -1.0
# 1940  About KIPP Bay Area Public SchoolsKIPP is a no...    -1.0
#
#                        Company Name           Location       Headquarters  \
# 1816    Staffigo Technical Services      Charlotte, NC      Woodridge, IL
# 491        Counter Threat Solutions        Norfolk, VA         Reston, VA
# 647                      Technology        Burbank, CA  Bishnupur , India
# 2181            Edison Software Inc         Denver, CO       San Jose, CA
# 551                 Tilde Staff Inc       Pasadena, CA       Pasadena, CA
# ...                             ...                ...                ...
# 1915                            Inc  San Francisco, CA       Bethesda, MD
# 547                          Kharon    Los Angeles, CA    Los Angeles, CA
# 558            Next Deavor Services         Carson, CA                 -1
# 1120     Kforce Technology Staffing     Wilmington, DE                 -1
# 1940  Albany Charter School Network        Oakland, CA                 -1
#
#                      Size  Founded  Type of ownership  \
# 1816  51 to 200 employees     2008  Company - Private
# 491   51 to 200 employees     2015  Company - Private
# 647               Unknown       -1  Company - Private
# 2181  51 to 200 employees       -1  Company - Private
# 551     1 to 50 employees       -1  Company - Private
# ...                   ...      ...                ...
# 1915    1 to 50 employees     1996  Company - Private
# 547   51 to 200 employees     2017   Company - Public
# 558                    -1       -1                 -1
# 1120                   -1       -1                 -1
# 1940                   -1       -1                 -1
#
#                                   Industry                  Sector  \
# 1816                           IT Services  Information Technology
# 491                             Consulting       Business Services
# 647                                     -1                      -1
# 2181          Computer Hardware & Software  Information Technology
# 551                                     -1                      -1
# ...                                    ...                     ...
# 1915  Architectural & Engineering Services       Business Services
# 547                                     -1                      -1
# 558                                     -1                      -1
# 1120                                    -1                      -1
# 1940                                    -1                      -1
#
#                         Revenue Competitors Easy Apply
# 1816  $50 to $100 million (USD)          -1         -1
# 491    Unknown / Non-Applicable          -1         -1
# 647    Unknown / Non-Applicable          -1         -1
# 2181     $1 to $5 million (USD)          -1         -1
# 551    Unknown / Non-Applicable          -1         -1
# ...                         ...         ...        ...
# 1915     $1 to $5 million (USD)          -1         -1
# 547     $5 to $10 million (USD)          -1         -1
# 558                          -1          -1         -1
# 1120                         -1          -1         -1
# 1940                         -1          -1         -1
#
# [2253 rows x 15 columns]

# %%
#Primero obtenemos los salarios promedios haciendo DataCleaning

salary = list(dict(data['Salary Estimate']).values())

minim = [' '.join(re.findall('\d+K-',str(element))) for element in salary]

maxim = [' '.join(re.findall('\W\W+\d+K',str(element))) for element in salary]
#print(minim)

minim_kclean = [re.sub('K-', '000', element) for element in minim]
maxim_kclean = [re.sub('K', '000', element) for element in maxim]
maxim_others = [re.sub('\W\W', '', element) for element in maxim_kclean]
#print(minim_kclean)

minim_kclean = [re.sub('', '0', element) for element in minim_kclean]
maxim_others = [re.sub('', '0', element) for element in maxim_others]
#print(maxim_others)

minim = [int(element) for element in minim_kclean]
maxim = [int(element) for element in maxim_others]
#print(len(minim))

avr_salary = [((int(minim[element]) + int(maxim[element])/2)) for element in range(len(minim))]
#print(len(avr_salary))
data.drop('Salary Estimate', axis = 1, inplace = True)
data['Salary Estimate'] = avr_salary
print(data['Salary Estimate'])
# Out:
# 1816    9.030000e+09
# 491     5.460000e+10
# 647     7.050000e+09
# 2181    8.105000e+09
# 551     6.570000e+09
#             ...
# 1915    6.263000e+10
# 547     6.570000e+09
# 558     6.570000e+09
# 1120    6.120000e+09
# 1940    6.263000e+10
# Name: Salary Estimate, Length: 2253, dtype: float64

# %%
#Despues agrupamos por Job Title y obtenemos el salario promedio para las posiciones


jobs_payment = data.groupby(['Job Title']).agg('mean')['Salary Estimate']
jobs_payment = jobs_payment.sort_values(ascending=False)
jobs_payment
# Out:
# Job Title
# Data Analyst, Autonomy Operations                 1.555000e+11
# AI Insights Data Analyst                          1.555000e+11
# Data Analyst, Product Insights                    1.555000e+11
# Senior HR Data Analyst                            1.555000e+11
# Data Analyst (SQL, Hive)                          1.555000e+11
#                                                       ...
# Business Analyst Data Governance                  3.630000e+09
# Cost Data Analyst                                 3.630000e+09
# Data Analyst & Healthcare Analytics               3.630000e+09
# Business Analyst (Data Integration/Salesforce)    3.630000e+09
# Configuration/Data Management Analyst III         0.000000e+00
# Name: Salary Estimate, Length: 1272, dtype: float64

# %%
#Exportamos el DataSet
jobs_payment.to_excel('salarios a aspirar.xlsx')

# %%
#payment = pd.DataFrame(jobs_payment, columns = ['Job Title', 'Salary Estimate'])
payment = pd.DataFrame(jobs_payment.reset_index())

payment = payment.iloc[:40,]

print(payment)
#tamaños
plt.figure(figsize=(20,10))
#Agregar titulo
plt.title('Posiciones mejor pagadas', fontsize = 14)

plt.xticks(rotation = 'vertical')
plt.bar(payment['Job Title'], payment['Salary Estimate'])
plt.show()
# Out:
#                                             Job Title  Salary Estimate
# 0                   Data Analyst, Autonomy Operations     1.555000e+11
# 1                            AI Insights Data Analyst     1.555000e+11
# 2                      Data Analyst, Product Insights     1.555000e+11
# 3                              Senior HR Data Analyst     1.555000e+11
# 4                            Data Analyst (SQL, Hive)     1.555000e+11
# 5      Senior Data Analyst Studio Finance Engineering     1.555000e+11
# 6                Sr. Data Analyst - Growth & Adoption     1.555000e+11
# 7                         Tableau Data Analyst Intern     1.555000e+11
# 8              Data Analyst with Data Mapping and API     1.555000e+11
# 9           19-0574 - Service Operations Data Analyst     1.525400e+11
# 10                          Data Analyst-HEDIS & Star     1.525400e+11
# 11           Data Entry Clerk and Analyst - Financial     1.525400e+11
# 12                           Systems and Data Analyst     1.525400e+11
# 13                            System and Data Analyst     1.525400e+11
# 14                             Discovery Data Analyst     1.525400e+11
# 15             Business Analyst Asset Data Management     1.525400e+11
# 16                           LIMS Master Data Analyst     1.525400e+11
# 17                       Music Copyright Data Analyst     1.525400e+11
# 18                  Radar Telemetry Data Analyst - RT     1.525400e+11
# 19                       Sr. Data Analyst — US Safety     1.525400e+11
# 20                        Sr. Data Analyst (Pharmacy)     1.525400e+11
# 21                       Senior Clinical Data Analyst     1.525400e+11
# 22                     Analyst, Financial Master Data     1.525400e+11
# 23    Sr Digital Marketing Data Analyst (PAID SOCIAL)     1.525400e+11
# 24       QM DATA ANALYST II, WHITTIER, FULL TIME DAYS     1.525400e+11
# 25                                   Sr Analyst, Data     1.525400e+11
# 26                      Data Analyst - Health, Senior     1.525400e+11
# 27                 Data Analyst - Marketing Analytics     1.525400e+11
# 28                           Data Analyst *Temp-Hire*     1.525400e+11
# 29                             Copyright Data Analyst     1.525400e+11
# 30                        Sr. Data Governance Analyst     8.920500e+10
# 31                    Service Operations Data Analyst     8.129750e+10
# 32                            SAP Master Data Analyst     8.129750e+10
# 33               Data Scientist/Analyst - Wilbur Labs     6.263000e+10
# 34      Data Analyst (College & Foundation Reporting)     6.263000e+10
# 35                                Data Studio Analyst     6.263000e+10
# 36         Business Intelligence Data Modeler/Analyst     6.263000e+10
# 37                                DATA Analyst-Remote     6.210250e+10
# 38                         Data and Policy Analyst IV     6.157500e+10
# 39  Business Data Analyst - Senior/Director - Work...     6.157500e+10
